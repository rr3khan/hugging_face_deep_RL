# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# For now we install this update of RL-Baselines3 Zoo
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo (to revision update/hf) to /tmp/pip-req-build-bcngvk9u
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-bcngvk9u
#   Running command git checkout -b update/hf --track origin/update/hf
#   Switched to a new branch 'update/hf'
#   Branch 'update/hf' set up to track remote branch 'update/hf' from 'origin'.
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 7dcbff7e74e7a12c052452181ff353a4dbed313a
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3-contrib>=2.0.0a9 (from rl-zoo3==2.0.0a9)
#   Downloading sb3_contrib-2.0.0a9-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 3.7 MB/s eta 0:00:00
# Collecting gym==0.26.2 (from rl-zoo3==2.0.0a9)
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 20.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting huggingface-sb3>=2.2.1 (from rl-zoo3==2.0.0a9)
#   Downloading huggingface_sb3-2.2.4-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from rl-zoo3==2.0.0a9) (4.65.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from rl-zoo3==2.0.0a9) (13.3.4)
# Collecting optuna (from rl-zoo3==2.0.0a9)
#   Downloading optuna-3.2.0-py3-none-any.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.6/390.6 kB 37.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from rl-zoo3==2.0.0a9) (6.0)
# Collecting pytablewriter~=0.64 (from rl-zoo3==2.0.0a9)
#   Downloading pytablewriter-0.64.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl-zoo3==2.0.0a9) (0.0.8)
# Collecting huggingface-hub~=0.8 (from huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 26.5 MB/s eta 0:00:00
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (1.1.1)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter~=0.64->rl-zoo3==2.0.0a9) (67.7.2)
# Collecting DataProperty<2,>=0.55.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading DataProperty-0.55.1-py3-none-any.whl (26 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading mbstrdecoder-1.1.2-py3-none-any.whl (7.7 kB)
# Collecting pathvalidate<3,>=2.3.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading pathvalidate-2.5.2-py3-none-any.whl (20 kB)
# Collecting tabledata<2,>=1.3.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading tabledata-1.3.1-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading tcolorpy-0.1.3-py3-none-any.whl (7.9 kB)
# Collecting typepy[datetime]<2,>=1.2.0 (from pytablewriter~=0.64->rl-zoo3==2.0.0a9)
#   Downloading typepy-1.3.0-py3-none-any.whl (31 kB)
# Collecting stable-baselines3>=2.0.0a9 (from sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9)
#   Downloading stable_baselines3-2.0.0a10-py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 22.4 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna->rl-zoo3==2.0.0a9)
#   Downloading alembic-1.11.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 26.0 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1 (from optuna->rl-zoo3==2.0.0a9)
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog (from optuna->rl-zoo3==2.0.0a9)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna->rl-zoo3==2.0.0a9) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna->rl-zoo3==2.0.0a9) (2.0.10)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->rl-zoo3==2.0.0a9) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->rl-zoo3==2.0.0a9) (2.14.0)
# Collecting Mako (from alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2.27.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->rl-zoo3==2.0.0a9) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (4.0.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna->rl-zoo3==2.0.0a9) (2.0.2)
# Collecting gymnasium==0.28.1 (from stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9)
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 43.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.0.1+cu118)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.7.1)
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9)
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Collecting farama-notifications>=0.0.1 (from gymnasium==0.28.1->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl-zoo3==2.0.0a9) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (16.0.5)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna->rl-zoo3==2.0.0a9) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl-zoo3==2.0.0a9) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11->stable-baselines3>=2.0.0a9->sb3-contrib>=2.0.0a9->rl-zoo3==2.0.0a9) (1.3.0)
# Building wheels for collected packages: rl-zoo3, gym
#   Building wheel for rl-zoo3 (pyproject.toml) ... done
#   Created wheel for rl-zoo3: filename=rl_zoo3-2.0.0a9-py3-none-any.whl size=76411 sha256=e3a6ad458428e8241ad872560227c0a022ffdc6e33fe5097055570b3f421be52
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ia848lop/wheels/fc/36/d5/2ef574649d85327de098075c8523da50be2612f3e5807261f7
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827634 sha256=b5d4cdb4d4c262a7608941005cf01ae8503a5d83650dfbf224cb1a0006422e57
#   Stored in directory: /root/.cache/pip/wheels/b9/22/6d/3e7b32d98451b4cd9d12417052affbeeeea012955d437da1da
# Successfully built rl-zoo3 gym
# Installing collected packages: farama-notifications, tcolorpy, pathvalidate, mbstrdecoder, Mako, jax-jumpy, gym, colorlog, cmaes, typepy, huggingface-hub, gymnasium, alembic, optuna, huggingface-sb3, DataProperty, tabledata, pytablewriter, stable-baselines3, sb3-contrib, rl-zoo3
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.0.6 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# Successfully installed DataProperty-0.55.1 Mako-1.2.4 alembic-1.11.1 cmaes-0.9.1 colorlog-6.7.0 farama-notifications-0.0.4 gym-0.26.2 gymnasium-0.28.1 huggingface-hub-0.15.1 huggingface-sb3-2.2.4 jax-jumpy-1.0.0 mbstrdecoder-1.1.2 optuna-3.2.0 pathvalidate-2.5.2 pytablewriter-0.64.2 rl-zoo3-2.0.0a9 sb3-contrib-2.0.0a9 stable-baselines3-2.0.0a10 tabledata-1.3.1 tcolorpy-0.1.3 typepy-1.3.0

# %% [markdown]
# IF AND ONLY IF THE VERSION ABOVE DOES NOT EXIST ANYMORE. UNCOMMENT AND INSTALL THE ONE BELOW

# %%
#!pip install rl_zoo3==2.0.0a9

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.16.3-1ubuntu1.20.04.1).
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 34 not upgraded.
# Need to get 1,086 kB of archives.
# After this operation, 5,413 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 swig4.0 amd64 4.0.1-5build1 [1,081 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 swig all 4.0.1-5build1 [5,528 B]
# Fetched 1,086 kB in 0s (2,531 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 122542 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.1-5build1_amd64.deb ...
# Unpacking swig4.0 (4.0.1-5build1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.1-5build1_all.deb ...
# Unpacking swig (4.0.1-5build1) ...
# Setting up swig4.0 (4.0.1-5build1) ...
# Setting up swig (4.0.1-5build1) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
# !nvidia-smi
# Out:
# Thu Jun  1 21:03:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.10/dist-packages (0.28.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (1.22.4)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (0.0.4)
# Collecting shimmy[atari]<1.0,>=0.1.0 (from gymnasium[atari])
#   Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Collecting ale-py~=0.8.1 (from shimmy[atari]<1.0,>=0.1.0->gymnasium[atari])
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 26.5 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0->gymnasium[atari]) (5.12.0)
# Installing collected packages: ale-py, shimmy
# Successfully installed ale-py-0.8.1 shimmy-0.2.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gymnasium[accept-rom-license] in /usr/local/lib/python3.10/dist-packages (0.28.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (1.22.4)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (0.0.4)
# Collecting autorom[accept-rom-license]~=0.4.2 (from gymnasium[accept-rom-license])
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (8.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (4.65.0)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 9.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (3.4)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=f576ab6b890a32d827fc87ba361d4ce96e40729c03a3d63e63e1a9d9f310097c
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.4.2

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e7
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %%
# !nvidia-smi
# Out:
# Thu Jun  1 21:08:20 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# !python -m rl_zoo3.train --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs/  -c dqn.yml
# Out:
# Streaming output truncated to the last 5000 lines.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.52e+03 |
# |    ep_rew_mean      | 487      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2460     |
# |    fps              | 247      |
# |    time_elapsed     | 2093     |
# |    total_timesteps  | 518545   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 104636   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.49e+03 |
# |    ep_rew_mean      | 483      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2464     |
# |    fps              | 247      |
# |    time_elapsed     | 2095     |
# |    total_timesteps  | 519073   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 104768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.5e+03  |
# |    ep_rew_mean      | 482      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2468     |
# |    fps              | 247      |
# |    time_elapsed     | 2101     |
# |    total_timesteps  | 520704   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0507   |
# |    n_updates        | 105175   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.53e+03 |
# |    ep_rew_mean      | 487      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2472     |
# |    fps              | 247      |
# |    time_elapsed     | 2107     |
# |    total_timesteps  | 521970   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0348   |
# |    n_updates        | 105492   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.53e+03 |
# |    ep_rew_mean      | 486      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2476     |
# |    fps              | 247      |
# |    time_elapsed     | 2112     |
# |    total_timesteps  | 523057   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0497   |
# |    n_updates        | 105764   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.52e+03 |
# |    ep_rew_mean      | 484      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2480     |
# |    fps              | 247      |
# |    time_elapsed     | 2114     |
# |    total_timesteps  | 523767   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0441   |
# |    n_updates        | 105941   |
# ----------------------------------
# Eval num_timesteps=525000, episode_reward=584.00 +/- 234.98
# Episode length: 3031.20 +/- 549.02
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.03e+03 |
# |    mean_reward      | 584      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 525000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 106249   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.51e+03 |
# |    ep_rew_mean      | 481      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2484     |
# |    fps              | 246      |
# |    time_elapsed     | 2129     |
# |    total_timesteps  | 525121   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0476   |
# |    n_updates        | 106280   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.53e+03 |
# |    ep_rew_mean      | 485      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2488     |
# |    fps              | 246      |
# |    time_elapsed     | 2136     |
# |    total_timesteps  | 526822   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 106705   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.54e+03 |
# |    ep_rew_mean      | 489      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2492     |
# |    fps              | 246      |
# |    time_elapsed     | 2140     |
# |    total_timesteps  | 527690   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0237   |
# |    n_updates        | 106922   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.53e+03 |
# |    ep_rew_mean      | 486      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2496     |
# |    fps              | 246      |
# |    time_elapsed     | 2145     |
# |    total_timesteps  | 528873   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.032    |
# |    n_updates        | 107218   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.53e+03 |
# |    ep_rew_mean      | 486      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2500     |
# |    fps              | 246      |
# |    time_elapsed     | 2149     |
# |    total_timesteps  | 530021   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 107505   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.52e+03 |
# |    ep_rew_mean      | 481      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2504     |
# |    fps              | 246      |
# |    time_elapsed     | 2154     |
# |    total_timesteps  | 531056   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 107763   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.53e+03 |
# |    ep_rew_mean      | 486      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2508     |
# |    fps              | 246      |
# |    time_elapsed     | 2160     |
# |    total_timesteps  | 532604   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 108150   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.52e+03 |
# |    ep_rew_mean      | 485      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2512     |
# |    fps              | 246      |
# |    time_elapsed     | 2164     |
# |    total_timesteps  | 533681   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0257   |
# |    n_updates        | 108420   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.52e+03 |
# |    ep_rew_mean      | 482      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2516     |
# |    fps              | 246      |
# |    time_elapsed     | 2169     |
# |    total_timesteps  | 534714   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 108678   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.55e+03 |
# |    ep_rew_mean      | 487      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2520     |
# |    fps              | 246      |
# |    time_elapsed     | 2176     |
# |    total_timesteps  | 536525   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 109131   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.56e+03 |
# |    ep_rew_mean      | 488      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2524     |
# |    fps              | 246      |
# |    time_elapsed     | 2180     |
# |    total_timesteps  | 537545   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.03     |
# |    n_updates        | 109386   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.54e+03 |
# |    ep_rew_mean      | 485      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2528     |
# |    fps              | 246      |
# |    time_elapsed     | 2187     |
# |    total_timesteps  | 538961   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0332   |
# |    n_updates        | 109740   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.56e+03 |
# |    ep_rew_mean      | 490      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2532     |
# |    fps              | 246      |
# |    time_elapsed     | 2192     |
# |    total_timesteps  | 540404   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.03     |
# |    n_updates        | 110100   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.56e+03 |
# |    ep_rew_mean      | 489      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2536     |
# |    fps              | 246      |
# |    time_elapsed     | 2195     |
# |    total_timesteps  | 541127   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.032    |
# |    n_updates        | 110281   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.56e+03 |
# |    ep_rew_mean      | 490      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2540     |
# |    fps              | 246      |
# |    time_elapsed     | 2202     |
# |    total_timesteps  | 542541   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0173   |
# |    n_updates        | 110635   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.56e+03 |
# |    ep_rew_mean      | 491      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2544     |
# |    fps              | 246      |
# |    time_elapsed     | 2206     |
# |    total_timesteps  | 543591   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0266   |
# |    n_updates        | 110897   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.57e+03 |
# |    ep_rew_mean      | 492      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2548     |
# |    fps              | 246      |
# |    time_elapsed     | 2210     |
# |    total_timesteps  | 544719   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0275   |
# |    n_updates        | 111179   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.58e+03 |
# |    ep_rew_mean      | 491      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2552     |
# |    fps              | 246      |
# |    time_elapsed     | 2217     |
# |    total_timesteps  | 546144   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0149   |
# |    n_updates        | 111535   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 495      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2556     |
# |    fps              | 246      |
# |    time_elapsed     | 2220     |
# |    total_timesteps  | 547099   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 111774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 498      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2560     |
# |    fps              | 246      |
# |    time_elapsed     | 2229     |
# |    total_timesteps  | 549052   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00995  |
# |    n_updates        | 112262   |
# ----------------------------------
# Eval num_timesteps=550000, episode_reward=540.00 +/- 180.08
# Episode length: 4154.40 +/- 952.09
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.15e+03 |
# |    mean_reward      | 540      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 550000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0341   |
# |    n_updates        | 112499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | 500      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2564     |
# |    fps              | 244      |
# |    time_elapsed     | 2248     |
# |    total_timesteps  | 550848   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0503   |
# |    n_updates        | 112711   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.64e+03 |
# |    ep_rew_mean      | 505      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2568     |
# |    fps              | 244      |
# |    time_elapsed     | 2253     |
# |    total_timesteps  | 552073   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0203   |
# |    n_updates        | 113018   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | 503      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2572     |
# |    fps              | 244      |
# |    time_elapsed     | 2260     |
# |    total_timesteps  | 553744   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0186   |
# |    n_updates        | 113435   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | 505      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2576     |
# |    fps              | 244      |
# |    time_elapsed     | 2264     |
# |    total_timesteps  | 554720   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.105    |
# |    n_updates        | 113679   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | 506      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2580     |
# |    fps              | 244      |
# |    time_elapsed     | 2269     |
# |    total_timesteps  | 555887   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0344   |
# |    n_updates        | 113971   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | 504      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2584     |
# |    fps              | 244      |
# |    time_elapsed     | 2278     |
# |    total_timesteps  | 557878   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0266   |
# |    n_updates        | 114469   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | 504      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2588     |
# |    fps              | 244      |
# |    time_elapsed     | 2284     |
# |    total_timesteps  | 559506   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0348   |
# |    n_updates        | 114876   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | 512      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2592     |
# |    fps              | 244      |
# |    time_elapsed     | 2293     |
# |    total_timesteps  | 561592   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 115397   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | 512      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2596     |
# |    fps              | 244      |
# |    time_elapsed     | 2299     |
# |    total_timesteps  | 563109   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0257   |
# |    n_updates        | 115777   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | 513      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2600     |
# |    fps              | 244      |
# |    time_elapsed     | 2306     |
# |    total_timesteps  | 564688   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 116171   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | 509      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2604     |
# |    fps              | 244      |
# |    time_elapsed     | 2310     |
# |    total_timesteps  | 565689   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 116422   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | 508      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2608     |
# |    fps              | 244      |
# |    time_elapsed     | 2315     |
# |    total_timesteps  | 566941   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0417   |
# |    n_updates        | 116735   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65e+03 |
# |    ep_rew_mean      | 507      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2612     |
# |    fps              | 244      |
# |    time_elapsed     | 2319     |
# |    total_timesteps  | 567859   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0423   |
# |    n_updates        | 116964   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | 507      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2616     |
# |    fps              | 244      |
# |    time_elapsed     | 2324     |
# |    total_timesteps  | 569035   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0299   |
# |    n_updates        | 117258   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | 506      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2620     |
# |    fps              | 244      |
# |    time_elapsed     | 2329     |
# |    total_timesteps  | 570360   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 117589   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | 506      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2624     |
# |    fps              | 244      |
# |    time_elapsed     | 2334     |
# |    total_timesteps  | 571480   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 117869   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | 505      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2628     |
# |    fps              | 244      |
# |    time_elapsed     | 2339     |
# |    total_timesteps  | 572626   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0257   |
# |    n_updates        | 118156   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 502      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2632     |
# |    fps              | 244      |
# |    time_elapsed     | 2343     |
# |    total_timesteps  | 573829   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.042    |
# |    n_updates        | 118457   |
# ----------------------------------
# Eval num_timesteps=575000, episode_reward=648.00 +/- 141.58
# Episode length: 4371.00 +/- 940.09
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.37e+03 |
# |    mean_reward      | 648      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 575000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 118749   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | 504      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2636     |
# |    fps              | 243      |
# |    time_elapsed     | 2363     |
# |    total_timesteps  | 575462   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 118865   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.64e+03 |
# |    ep_rew_mean      | 510      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2640     |
# |    fps              | 243      |
# |    time_elapsed     | 2368     |
# |    total_timesteps  | 576529   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0135   |
# |    n_updates        | 119132   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | 507      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2644     |
# |    fps              | 243      |
# |    time_elapsed     | 2373     |
# |    total_timesteps  | 577827   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 119456   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | 509      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2648     |
# |    fps              | 243      |
# |    time_elapsed     | 2375     |
# |    total_timesteps  | 578293   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0203   |
# |    n_updates        | 119573   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 505      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2652     |
# |    fps              | 243      |
# |    time_elapsed     | 2379     |
# |    total_timesteps  | 579082   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0476   |
# |    n_updates        | 119770   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 505      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2656     |
# |    fps              | 243      |
# |    time_elapsed     | 2386     |
# |    total_timesteps  | 580791   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 120197   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | 505      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2660     |
# |    fps              | 243      |
# |    time_elapsed     | 2391     |
# |    total_timesteps  | 582091   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 120522   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | 505      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2664     |
# |    fps              | 243      |
# |    time_elapsed     | 2396     |
# |    total_timesteps  | 583168   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0284   |
# |    n_updates        | 120791   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | 505      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2668     |
# |    fps              | 243      |
# |    time_elapsed     | 2404     |
# |    total_timesteps  | 585401   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0301   |
# |    n_updates        | 121350   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | 510      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2672     |
# |    fps              | 243      |
# |    time_elapsed     | 2407     |
# |    total_timesteps  | 586049   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0339   |
# |    n_updates        | 121512   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.63e+03 |
# |    ep_rew_mean      | 510      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2676     |
# |    fps              | 243      |
# |    time_elapsed     | 2415     |
# |    total_timesteps  | 588015   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0251   |
# |    n_updates        | 122003   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | 506      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2680     |
# |    fps              | 243      |
# |    time_elapsed     | 2418     |
# |    total_timesteps  | 588657   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0294   |
# |    n_updates        | 122164   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 503      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2684     |
# |    fps              | 243      |
# |    time_elapsed     | 2425     |
# |    total_timesteps  | 590076   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0269   |
# |    n_updates        | 122518   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | 503      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2688     |
# |    fps              | 243      |
# |    time_elapsed     | 2429     |
# |    total_timesteps  | 591182   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 122795   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | 504      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2692     |
# |    fps              | 243      |
# |    time_elapsed     | 2436     |
# |    total_timesteps  | 592905   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0455   |
# |    n_updates        | 123226   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.61e+03 |
# |    ep_rew_mean      | 506      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2696     |
# |    fps              | 243      |
# |    time_elapsed     | 2442     |
# |    total_timesteps  | 594139   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.058    |
# |    n_updates        | 123534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.59e+03 |
# |    ep_rew_mean      | 503      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2700     |
# |    fps              | 243      |
# |    time_elapsed     | 2445     |
# |    total_timesteps  | 594905   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0224   |
# |    n_updates        | 123726   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | 506      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2704     |
# |    fps              | 243      |
# |    time_elapsed     | 2450     |
# |    total_timesteps  | 596442   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 124110   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | 504      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2708     |
# |    fps              | 243      |
# |    time_elapsed     | 2457     |
# |    total_timesteps  | 597815   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 124453   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62e+03 |
# |    ep_rew_mean      | 502      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2712     |
# |    fps              | 243      |
# |    time_elapsed     | 2461     |
# |    total_timesteps  | 598913   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.024    |
# |    n_updates        | 124728   |
# ----------------------------------
# Eval num_timesteps=600000, episode_reward=557.00 +/- 115.35
# Episode length: 4002.00 +/- 666.97
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4e+03    |
# |    mean_reward      | 557      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 600000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0553   |
# |    n_updates        | 124999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | 511      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2716     |
# |    fps              | 242      |
# |    time_elapsed     | 2484     |
# |    total_timesteps  | 601537   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.058    |
# |    n_updates        | 125384   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | 510      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2720     |
# |    fps              | 242      |
# |    time_elapsed     | 2491     |
# |    total_timesteps  | 603325   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 125831   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68e+03 |
# |    ep_rew_mean      | 512      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2724     |
# |    fps              | 242      |
# |    time_elapsed     | 2493     |
# |    total_timesteps  | 603951   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 125987   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.67e+03 |
# |    ep_rew_mean      | 507      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2728     |
# |    fps              | 242      |
# |    time_elapsed     | 2498     |
# |    total_timesteps  | 604949   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0316   |
# |    n_updates        | 126237   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | 505      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2732     |
# |    fps              | 242      |
# |    time_elapsed     | 2506     |
# |    total_timesteps  | 606849   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0534   |
# |    n_updates        | 126712   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.68e+03 |
# |    ep_rew_mean      | 508      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2736     |
# |    fps              | 242      |
# |    time_elapsed     | 2510     |
# |    total_timesteps  | 607970   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 126992   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.69e+03 |
# |    ep_rew_mean      | 513      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2740     |
# |    fps              | 242      |
# |    time_elapsed     | 2516     |
# |    total_timesteps  | 609209   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0105   |
# |    n_updates        | 127302   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | 518      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2744     |
# |    fps              | 242      |
# |    time_elapsed     | 2521     |
# |    total_timesteps  | 610616   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0251   |
# |    n_updates        | 127653   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | 523      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2748     |
# |    fps              | 242      |
# |    time_elapsed     | 2529     |
# |    total_timesteps  | 612352   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 128087   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | 527      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2752     |
# |    fps              | 242      |
# |    time_elapsed     | 2534     |
# |    total_timesteps  | 613683   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0223   |
# |    n_updates        | 128420   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | 526      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2756     |
# |    fps              | 242      |
# |    time_elapsed     | 2539     |
# |    total_timesteps  | 614859   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 128714   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | 529      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2760     |
# |    fps              | 242      |
# |    time_elapsed     | 2545     |
# |    total_timesteps  | 616292   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 129072   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | 525      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2764     |
# |    fps              | 242      |
# |    time_elapsed     | 2549     |
# |    total_timesteps  | 617227   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0142   |
# |    n_updates        | 129306   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | 527      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2768     |
# |    fps              | 242      |
# |    time_elapsed     | 2557     |
# |    total_timesteps  | 619154   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 129788   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | 524      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2772     |
# |    fps              | 242      |
# |    time_elapsed     | 2563     |
# |    total_timesteps  | 620480   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0347   |
# |    n_updates        | 130119   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | 528      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2776     |
# |    fps              | 242      |
# |    time_elapsed     | 2567     |
# |    total_timesteps  | 621662   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 130415   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 529      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2780     |
# |    fps              | 242      |
# |    time_elapsed     | 2574     |
# |    total_timesteps  | 623149   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 130787   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | 527      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2784     |
# |    fps              | 242      |
# |    time_elapsed     | 2578     |
# |    total_timesteps  | 624043   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0528   |
# |    n_updates        | 131010   |
# ----------------------------------
# Eval num_timesteps=625000, episode_reward=634.00 +/- 123.26
# Episode length: 3931.60 +/- 387.17
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.93e+03 |
# |    mean_reward      | 634      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 625000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0404   |
# |    n_updates        | 131249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | 524      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2788     |
# |    fps              | 240      |
# |    time_elapsed     | 2594     |
# |    total_timesteps  | 625294   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0239   |
# |    n_updates        | 131323   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | 524      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2792     |
# |    fps              | 240      |
# |    time_elapsed     | 2602     |
# |    total_timesteps  | 627163   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0319   |
# |    n_updates        | 131790   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.71e+03 |
# |    ep_rew_mean      | 519      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2796     |
# |    fps              | 240      |
# |    time_elapsed     | 2608     |
# |    total_timesteps  | 628595   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 132148   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | 520      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2800     |
# |    fps              | 240      |
# |    time_elapsed     | 2612     |
# |    total_timesteps  | 629523   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0195   |
# |    n_updates        | 132380   |
# ----------------------------------
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0483   |
# |    n_updates        | 212958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07e+03 |
# |    ep_rew_mean      | 583      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3600     |
# |    fps              | 232      |
# |    time_elapsed     | 4105     |
# |    total_timesteps  | 953615   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 213403   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 581      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3604     |
# |    fps              | 232      |
# |    time_elapsed     | 4109     |
# |    total_timesteps  | 954659   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 213664   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 580      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3608     |
# |    fps              | 232      |
# |    time_elapsed     | 4115     |
# |    total_timesteps  | 956208   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0234   |
# |    n_updates        | 214051   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 586      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3612     |
# |    fps              | 232      |
# |    time_elapsed     | 4125     |
# |    total_timesteps  | 958363   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 214590   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 585      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3616     |
# |    fps              | 232      |
# |    time_elapsed     | 4130     |
# |    total_timesteps  | 959818   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0465   |
# |    n_updates        | 214954   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13e+03 |
# |    ep_rew_mean      | 587      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3620     |
# |    fps              | 232      |
# |    time_elapsed     | 4141     |
# |    total_timesteps  | 962363   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 215590   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 587      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3624     |
# |    fps              | 232      |
# |    time_elapsed     | 4144     |
# |    total_timesteps  | 963135   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0105   |
# |    n_updates        | 215783   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14e+03 |
# |    ep_rew_mean      | 589      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3628     |
# |    fps              | 232      |
# |    time_elapsed     | 4151     |
# |    total_timesteps  | 964740   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0436   |
# |    n_updates        | 216184   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15e+03 |
# |    ep_rew_mean      | 591      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3632     |
# |    fps              | 232      |
# |    time_elapsed     | 4160     |
# |    total_timesteps  | 967283   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 216820   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.15e+03 |
# |    ep_rew_mean      | 591      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3636     |
# |    fps              | 232      |
# |    time_elapsed     | 4173     |
# |    total_timesteps  | 970205   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 217551   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17e+03 |
# |    ep_rew_mean      | 594      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3640     |
# |    fps              | 232      |
# |    time_elapsed     | 4178     |
# |    total_timesteps  | 971520   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00743  |
# |    n_updates        | 217879   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14e+03 |
# |    ep_rew_mean      | 587      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3644     |
# |    fps              | 232      |
# |    time_elapsed     | 4183     |
# |    total_timesteps  | 972613   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.035    |
# |    n_updates        | 218153   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14e+03 |
# |    ep_rew_mean      | 587      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3648     |
# |    fps              | 232      |
# |    time_elapsed     | 4190     |
# |    total_timesteps  | 974392   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 218597   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=538.00 +/- 48.12
# Episode length: 4092.20 +/- 262.76
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.09e+03 |
# |    mean_reward      | 538      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0212   |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.14e+03 |
# |    ep_rew_mean      | 587      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3652     |
# |    fps              | 231      |
# |    time_elapsed     | 4206     |
# |    total_timesteps  | 975506   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 218876   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13e+03 |
# |    ep_rew_mean      | 586      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3656     |
# |    fps              | 231      |
# |    time_elapsed     | 4213     |
# |    total_timesteps  | 976889   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0407   |
# |    n_updates        | 219222   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | 582      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3660     |
# |    fps              | 231      |
# |    time_elapsed     | 4218     |
# |    total_timesteps  | 978197   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 219549   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 578      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3664     |
# |    fps              | 231      |
# |    time_elapsed     | 4225     |
# |    total_timesteps  | 979988   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 219996   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 575      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3668     |
# |    fps              | 231      |
# |    time_elapsed     | 4230     |
# |    total_timesteps  | 981234   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0205   |
# |    n_updates        | 220308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 568      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3672     |
# |    fps              | 231      |
# |    time_elapsed     | 4236     |
# |    total_timesteps  | 982613   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 220653   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 569      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3676     |
# |    fps              | 231      |
# |    time_elapsed     | 4241     |
# |    total_timesteps  | 983666   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 220916   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 575      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3680     |
# |    fps              | 231      |
# |    time_elapsed     | 4251     |
# |    total_timesteps  | 986422   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 221605   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07e+03 |
# |    ep_rew_mean      | 578      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3684     |
# |    fps              | 231      |
# |    time_elapsed     | 4259     |
# |    total_timesteps  | 988010   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 222002   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 580      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3688     |
# |    fps              | 232      |
# |    time_elapsed     | 4266     |
# |    total_timesteps  | 989817   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0317   |
# |    n_updates        | 222454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 582      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3692     |
# |    fps              | 232      |
# |    time_elapsed     | 4270     |
# |    total_timesteps  | 990766   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 222691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | 589      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3696     |
# |    fps              | 232      |
# |    time_elapsed     | 4281     |
# |    total_timesteps  | 993667   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.018    |
# |    n_updates        | 223416   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16e+03 |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3700     |
# |    fps              | 232      |
# |    time_elapsed     | 4290     |
# |    total_timesteps  | 995601   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0232   |
# |    n_updates        | 223900   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3704     |
# |    fps              | 232      |
# |    time_elapsed     | 4293     |
# |    total_timesteps  | 996607   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0642   |
# |    n_updates        | 224151   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18e+03 |
# |    ep_rew_mean      | 594      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3708     |
# |    fps              | 232      |
# |    time_elapsed     | 4300     |
# |    total_timesteps  | 998154   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0255   |
# |    n_updates        | 224538   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=647.00 +/- 142.81
# Episode length: 4356.60 +/- 1027.14
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.36e+03 |
# |    mean_reward      | 647      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.034    |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_1

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# 2023-06-01 22:33:55.734331: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-01 22:33:56.666545: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 540.00
# Atari Episode Length 4869
# Atari Episode Score: 580.00
# Atari Episode Length 3821
# Atari Episode Score: 600.00
# Atari Episode Length 4571
# Atari Episode Score: 515.00
# Atari Episode Length 4957

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name SpaceInvadersNoFrameskip-v4 -orga rr3khan -f logs/
# Out:
# 2023-06-01 22:35:24.004781: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-01 22:35:25.323491: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to rr3khan/SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Cloning https://huggingface.co/rr3khan/SpaceInvadersNoFrameskip-v4 into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/rr3khan/SpaceInvadersNoFrameskip-v4 into local empty directory.
# Saving model to: hub/SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:364: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Saving video to /tmp/tmpkd0hlmed/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmpkd0hlmed/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpkd0hlmed/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpkd0hlmed/-step-0-to-step-1000.mp4
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmpkd0hlmed/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.40, start: 0.000000, bitrate: 54 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 160x210, 52 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x558d3e546280] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x558d3e546280] profile High, level 1.2
# [libx264 @ 0x558d3e546280] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'hub/SpaceInvadersNoFrameskip-v4/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 160x210, q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame= 1002 fps=0.0 q=-1.0 Lsize=     218kB time=00:00:33.30 bitrate=  53.7kbits/s speed=38.7x
# video:207kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.224535%
# [libx264 @ 0x558d3e546280] frame I:5     Avg QP:16.86  size:  2798
# [libx264 @ 0x558d3e546280] frame P:507   Avg QP:22.30  size:   340
# [libx264 @ 0x558d3e546280] frame B:490   Avg QP:28.51  size:    52
# [libx264 @ 0x558d3e546280] consecutive B-frames: 28.5% 16.0%  8.4% 47.1%
# [libx264 @ 0x558d3e546280] mb I  I16..4: 26.4% 36.7% 36.9%
# [libx264 @ 0x558d3e546280] mb P  I16..4:  0.4%  0.9%  0.8%  P16..4:  7.6%  2.8%  1.7%  0.0%  0.0%    skip:85.7%
# [libx264 @ 0x558d3e546280] mb B  I16..4:  0.1%  0.2%  0.1%  B16..8:  9.7%  0.9%  0.1%  direct: 0.2%  skip:88.7%  L0:48.9% L1:50.7% BI: 0.4%
# [libx264 @ 0x558d3e546280] 8x8 transform intra:40.8% inter:5.7%
# [libx264 @ 0x558d3e546280] coded y,uvDC,uvAC intra: 21.2% 36.7% 34.3% inter: 1.5% 1.9% 1.6%
# [libx264 @ 0x558d3e546280] i16 v,h,dc,p: 45% 48%  7%  0%
# [libx264 @ 0x558d3e546280] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22%  9% 68%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x558d3e546280] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 12% 41%  2%  2%  2%  1%  2%  1%
# [libx264 @ 0x558d3e546280] i8c dc,h,v,p: 55% 30% 13%  1%
# [libx264 @ 0x558d3e546280] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x558d3e546280] ref P L0: 75.3%  5.4%  9.8%  9.4%
# [libx264 @ 0x558d3e546280] ref B L0: 84.8% 11.8%  3.3%
# [libx264 @ 0x558d3e546280] ref B L1: 96.6%  3.4%
# [libx264 @ 0x558d3e546280] kb/s:50.69
# ℹ Pushing repo SpaceInvadersNoFrameskip-v4 to the Hugging Face Hub
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   0% 1.00/26.0M [00:00<?, ?B/s]
# Upload file train_eval_metrics.zip:   0% 1.00/34.5k [00:00<?, ?B/s]
#
# Upload file replay.mp4:   0% 1.00/218k [00:00<?, ?B/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth:   0% 1.00/431 [00:00<?, ?B/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   0% 1.00/12.9M [00:00<?, ?B/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  59% 15.3M/26.0M [00:01<00:00, 15.9MB/s]To https://huggingface.co/rr3khan/SpaceInvadersNoFrameskip-v4
#    5a5da0a..a8003d4  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/rr3khan/SpaceInvadersNoFrameskip-v4
#    5a5da0a..a8003d4  main -> main
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 100% 26.0M/26.0M [00:02<00:00, 13.6MB/s]
#
# Upload file train_eval_metrics.zip: 100% 34.5k/34.5k [00:02<00:00, 7.98MB/s]
# Upload file train_eval_metrics.zip: 100% 34.5k/34.5k [00:02<00:00, 17.6kB/s]
#
#
# Upload file replay.mp4: 100% 218k/218k [00:02<00:00, 7.98MB/s]
#
# Upload file replay.mp4: 100% 218k/218k [00:02<00:00, 111kB/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100% 431/431 [00:02<00:00, 7.98MB/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100% 431/431 [00:02<00:00, 215B/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100% 12.9M/12.9M [00:02<00:00, 7.98MB/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100% 12.9M/12.9M [00:02<00:00, 6.74MB/s]
#
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100% 12.9M/12.9M [00:02<00:00, 7.98MB/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100% 12.9M/12.9M [00:02<00:00, 6.74MB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/rr3khan/SpaceInvadersNoFrameskip-v4

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/
# Out:
# 2023-06-01 22:36:54.230391: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-01 22:36:55.161041: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading from https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# Downloading (…)erNoFrameskip-v4.zip: 100% 27.2M/27.2M [00:00<00:00, 74.6MB/s]
# Downloading (…)olve/main/config.yml: 100% 548/548 [00:00<00:00, 3.76MB/s]
# No normalization file
# Downloading (…)esolve/main/args.yml: 100% 887/887 [00:00<00:00, 6.90MB/s]
# Downloading (…)/main/env_kwargs.yml: 100% 3.00/3.00 [00:00<00:00, 27.4kB/s]
# Downloading train_eval_metrics.zip: 100% 244k/244k [00:00<00:00, 7.23MB/s]
# Saving to rl_trained/dqn/BeamRiderNoFrameskip-v4_1

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
